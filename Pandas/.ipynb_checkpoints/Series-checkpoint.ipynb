# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Use List

# %%
contry = ["india","USA","NEPAL","SRILANKA"]
pd.Series(contry)
# Out:
# 0       india
# 1         USA
# 2       NEPAL
# 3    SRILANKA
# dtype: object

# %%
Run = [10,20,30,40]
Run_Series = pd.Series(Run)
Run_Series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
 pd.Series(Run, index =contry )
# Out:
# india       10
# USA         20
# NEPAL       30
# SRILANKA    40
# dtype: int64

# %%
 pd.Series(Run, index =contry , name = "Run" )
# Out:
# india       10
# USA         20
# NEPAL       30
# SRILANKA    40
# Name: Run, dtype: int64

# %% [markdown]
# # Use Dict

# %%
marks = {
    "mathe": 50,
    "English":60,
    "science":70,
    "Hindi":80,    }
marks_series=pd.Series(marks , name = "number of subjects marks")

# %% [markdown]
# # Series Attributes

# %%
# Size
marks_series.size
# Out:
# 4

# %%
# Dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
#Name
marks_series.name
# Out:
# 'number of subjects marks'

# %%
# is_unique
marks_series.is_unique

#no repeat value
# Out:
# True

# %%
# Index

a =marks_series.index
b= Run_Series.index
print(a,b)
# Out:
# Index(['mathe', 'English', 'science', 'Hindi'], dtype='object') RangeIndex(start=0, stop=4, step=1)

# %%
# value
marks_series.values
# Out:
# array([50, 60, 70, 80], dtype=int64)

# %% [markdown]
# # Seres Using read_csv

# %%
subs = pd.read_csv("subs.csv").squeeze(1)
print(subs)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
pd.read_csv("kohli_ipl.csv",index_col = "match_no").squeeze(1)
VK = pd.read_csv("kohli_ipl.csv",index_col = "match_no").squeeze(1)
print(VK)
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
pd.read_csv("bollywood.csv",index_col = "movie").squeeze(1)
bolly = pd.read_csv("bollywood.csv",index_col = "movie").squeeze(1)
bolly
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Head , Tail

# %%
subs.head(10)
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# 5    46
# 6    33
# 7    40
# 8    44
# 9    74
# Name: Subscribers gained, dtype: int64

# %%
VK.head(5)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
bolly.head()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
# Name: lead, dtype: object

# %%
subs.tail()
# Out:
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
# Sample
# random find one row

# %%
bolly.sample(5)
# Out:
# movie
# Hum Tum Aur Ghost             Arshad Warsi
# Dhadak                      Ishaan Khattar
# Happy Ending (film)          Saif Ali Khan
# Jayantabhai Ki Luv Story      Vivek Oberoi
# Blue (2009 film)              Akshay Kumar
# Name: lead, dtype: object

# %%
# Count

bolly.value_counts()
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Diganth              1
# Parveen Kaur         1
# Seema Azmi           1
# Akanksha Puri        1
# Edwin Fernandes      1
# Name: lead, Length: 566, dtype: int64

# %%
# sort Value
VK.sort_values(ascending = False).head(1).values[0]
# Out:
# 113

# %%
bolly.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Mathe Method in Pandas

# %%
# count()

# count is not count missing value

VK.count()
# Out:
# 215

# %%
# sum

VK.sum()
# Out:
# 6634

# %%
# mean , median , mode , std , var


VK.mean()
# Out:
# 30.855813953488372

# %%
VK.median()
# Out:
# 24.0

# %%
bolly.mode()
# Out:
# 0    Akshay Kumar
# Name: lead, dtype: object

# %%
VK.std()
# Out:
# 26.22980132830278

# %%
VK.var()
# Out:
# 688.0024777222343

# %%
# min , max


VK.min()
# Out:
# 0

# %%
VK.max()
# Out:
# 113

# %%
VK.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %%
bolly.describe()
# Out:
# count             1500
# unique             566
# top       Akshay Kumar
# freq                48
# Name: lead, dtype: object

# %% [markdown]
# # Serise Indexing

# %%
# Negative index not Work
# index is string then Negative index is work

# %%
VK[7]
# Out:
# 34

# %%
bolly[10]
# Out:
# 'Ali Asgar'

# %% [markdown]
# # Slicing

# %%
VK[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
bolly[1:10:2]
# Out:
# movie
# Battalion 609                Vicky Ahuja
# Why Cheat India            Emraan Hashmi
# Soni (film)         Geetika Vidya Ohlyan
# Bombairiya                  Radhika Apte
# Thackeray (film)     Nawazuddin Siddiqui
# Name: lead, dtype: object

# %%
# Fancy Indexing

VK[[1,2,3,5]]
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# 5     1
# Name: runs, dtype: int64

# %%
bolly[[1,9,7]]
# Out:
# movie
# Battalion 609               Vicky Ahuja
# Thackeray (film)    Nawazuddin Siddiqui
# Bombairiya                 Radhika Apte
# Name: lead, dtype: object

# %%
# lable use in indexing

bolly["Bombairiya"]
# Out:
# 'Radhika Apte'

# %% [markdown]
# # Editing Series

# %%
VK[5]=100
VK[5]
# Out:
# 100

# %%
VK[216] = 100

# %%
VK
# Out:
# match_no
# 1        1
# 2       23
# 3       13
# 4       12
# 5      100
#       ...
# 212     20
# 213     73
# 214     25
# 215      7
# 216    100
# Name: runs, Length: 216, dtype: int64

# %% [markdown]
# # Series With Python Functionalities

# %%
print(len(subs))
# Out:
# 365

# %%
print(type(subs))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(dir(subs))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__array_wrap__', '__bool__', '__class__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__long__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__rfloordiv__', '__rmatmul__',
# ...

# %%
print(sorted(subs)) #output iin list so it is not use
# Out:
# [33, 33, 35, 37, 39, 40, 40, 40, 40, 42, 42, 43, 44, 44, 44, 45, 46, 46, 48, 49, 49, 49, 49, 50, 50, 50, 51, 54, 56, 56, 56, 56, 57, 61, 62, 64, 65, 65, 66, 66, 66, 66, 67, 68, 70, 70, 70, 71, 71, 72, 72, 72, 72, 72, 73, 74, 74, 75, 76, 76, 76, 76, 77, 77, 78, 78, 78, 79, 79, 80, 80, 80, 81, 81, 82, 82, 83, 83, 83, 84, 84, 84, 85, 86, 86, 86, 87, 87, 87, 87, 88, 88, 88, 88, 88, 89, 89, 89, 90, 90, 90, 90, 91, 92, 92, 92, 93, 93, 93, 93, 95, 95, 96, 96, 96, 96, 97, 97, 98, 98, 99, 99, 100, 100, 100, 101, 101, 101, 102, 102, 103, 103, 104, 104, 104, 105, 105, 105, 105, 105, 105, 105, 105, 105, 108, 108, 108, 108, 108, 108, 109, 109, 110, 110, 110, 111, 111, 112, 113, 113, 113, 114, 114, 114, 114, 115, 115, 115, 115, 117, 117, 117, 118, 118, 119, 119, 119, 119, 120, 122, 123, 123, 123, 123, 123, 124, 125, 126, 127, 128, 128, 129, 130, 131, 131, 132, 132, 134, 134, 134, 135, 135, 136, 136, 136, 137, 138, 138, 138, 139, 140, 144, 145, 146, 146, 146, 146, 147, 149, 150, 150, 150, 150, 151,
# ...

# %%
print(max(subs))
# Out:
# 396

# %%
print(min(subs))
# Out:
# 33

# %%
# convert 

list(subs)
# Out:
# [48,
#  57,
#  40,
#  43,
#  44,
#  46,
#  33,
#  40,
#  44,
#  74,
#  49,
#  56,
#  49,
#  42,
#  39,
#  44,
#  54,
#  51,
#  40,
#  37,
#  40,
#  45,
#  50,
#  56,
#  35,
#  49,
#  46,
#  88,
#  61,
#  42,
#  56,
#  50,
#  50,
#  49,
#  76,
#  123,
#  108,
#  110,
#  56,
#  62,
#  65,
#  66,
#  33,
#  66,
#  82,
#  126,
#  109,
#  88,
#  83,
#  108,
#  101,
#  128,
#  111,
#  96,
#  101,
#  99,
#  105,
#  72,
#  93,
#  76,
#  104,
#  70,
#  80,
#  99,
#  104,
#  136,
#  115,
#  123,
#  112,
#  145,
#  87,
#  84,
#  92,
#  80,
#  70,
#  70,
#  132,
#  123,
#  98,
#  96,
#  88,
#  86,
#  92,
#  92,
#  110,
#  120,
#  105,
#  72,
#  84,
#  90,
#  78,
#  81,
#  89,
#  89,
#  93,
#  86,
#  95,
#  83,
#  72,
#  87,
#  100,
#  72,
#  79,
#  67,
#  71,
#  90,
#  77,
#  100,
#  88,
#  65,
#  95,
#  78,
#  89,
#  96,
#  81,
#  105,
#  80,
#  66,
#  73,
#  68,
#  159,
#  90,
#  83,
#  76,
#  77,
#  66,
#  64,
#  85,
#  136,
#  135,
#  71,
#  79,
#  75,
#  72,
#  78,
#  109,
#  93,
#  84,
# ...

# %%
# membership Oprater

# %%
# looping

for i in bolly:
    print(i)
# Out:
# Vicky Kaushal
# Vicky Ahuja
# Anupam Kher
# Emraan Hashmi
# Mona Ambegaonkar
# Geetika Vidya Ohlyan
# Arshad Warsi
# Radhika Apte
# Kangana Ranaut
# Nawazuddin Siddiqui
# Ali Asgar
# Ranveer Singh
# Prit Kamani
# Ajay Devgn
# Sushant Singh Rajput
# Amitabh Bachchan
# Abhimanyu Dasani
# Talha Arshad Reshi
# Nawazuddin Siddiqui
# Garima Agarwal
# Rasika Agashe
# Barun Sobti
# Akshay Kumar
# Zaheer Iqbal
# Vidyut Jammwal
# Deepika Amin
# Manav Kaul
# Naseeruddin Shah
# Varun Dhawan
# Shreyas Talpade
# Tiger Shroff
# Boman Irani
# Ajay Devgn
# Arjun Kapoor
# Gavie Chahal
# Prabhu Deva
# Shahid Kapoor
# Ayushmann Khurrana
# Anupam Kher
# Karanvir Bohra
# Hrithik Roshan
# Jimmy Sheirgill
# John Abraham
# Rishi Kapoor
# Kangana Ranaut
# Natalia Janoszek
# Diljit Dosanjh
# Sidharth Malhotra
# Rajeev Khandelwal
# Zaira Wasim
# Akshay Kumar
# Jacqueline Fernandez
# Ayushmann Khurrana
# Akshaye Khanna
# Sonam Kapoor
# Karan Deol
# Sanjay Dutt
# Bhavesh Kumar
# Sanaya Irani
# Ayushmann Khurrana
# ...

# %%
for i in bolly.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic 

100+marks_series
# Out:
# mathe      150
# English    160
# science    170
# Hindi      180
# Name: number of subjects marks, dtype: int64

# %%
# Relationship Operators 


VK[VK> 50]
# Out:
# match_no
# 5      100
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# 216    100
# Name: runs, dtype: int64

# %%
# Boolean Indexing On series
VK[VK>=50]
# Out:
# match_no
# 5      100
# 15      50
# 34      58
# 41      71
# 44      56
# 45      67
# 52      70
# 57      57
# 68      73
# 71      51
# 73      58
# 74      65
# 80      57
# 81      93
# 82      99
# 85      56
# 97      67
# 99      73
# 103     51
# 104     62
# 110     82
# 116     75
# 117     79
# 119     80
# 120    100
# 122     52
# 123    108
# 126    109
# 127     75
# 128    113
# 129     54
# 131     54
# 132     62
# 134     64
# 137     55
# 141     58
# 144     57
# 145     92
# 148     68
# 152     70
# 160     84
# 162     67
# 164    100
# 175     72
# 178     90
# 182     50
# 188     72
# 197     51
# 198     53
# 209     58
# 213     73
# 216    100
# Name: runs, dtype: int64

# %%
VK[VK==0].size
# Out:
# 9

# %%
num =bolly.value_counts()

# %%
num[num>20]
# Out:
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: lead, dtype: int64

# %% [markdown]
# # Plotting Graphs On series

# %%
subs.plot()
# Out:
# <AxesSubplot: >

# %%
bolly.value_counts().head(20).plot(kind = "pie")
# Out:
# <AxesSubplot: ylabel='lead'>

# %%
bolly.value_counts().head(20).plot(kind = "bar")
# Out:
# <AxesSubplot: >
